# %%
import pandas as pd

# Cargar el dataset de ecología que guardaste en tu carpeta 'data'
df = pd.read_csv("data/surveys.csv")

# Ver las primeras 5 filas del archivo
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2
#       3 # Cargar el dataset de ecología que guardaste en tu carpeta 'data'
#       4 df = pd.read_csv("data/surveys.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
# Cargar el dataset de ecología que guardaste en tu carpeta 'data'
df = pd.read_csv("data/surveys.csv")

# Ver las primeras 5 filas del archivo
df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Ver cuántos animales se capturaron de cada especie
df['species_id'].value_counts()
# Out:
# species_id
# DM    10596
# PP     3123
# DO     3027
# PB     2891
# RM     2609
# DS     2504
# OT     2249
# PF     1597
# PE     1299
# NL     1252
# OL     1006
# PM      899
# AH      437
# AB      303
# SS      248
# SH      147
# SA       75
# RF       75
# CB       50
# BA       46
# SF       43
# SO       43
# DX       40
# PC       39
# PL       36
# PH       32
# CQ       16
# CM       13
# OX       12
# UR       10
# PI        9
# PG        8
# UP        8
# RO        8
# PX        6
# PU        5
# SU        5
# UL        4
# US        4
# ZL        2
# AS        2
# RX        2
# CV        1
# CS        1
# SC        1
# ST        1
# CU        1
# CT        1
# Name: count, dtype: int64
